# %%
# ### Fine-Tuning YOLOv9 for Vehicle Detection

# Final Experiment #17

# Experiment Purpose: 
# Run yolov9.c model for PoribohonBD dataset (40 epochs)

# %%
# Check GPU
# !nvidia-smi
# Out:
# Thu May  9 19:39:21 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA H100                    On  | 00000000:84:00.0 Off |                   On |
# | N/A   23C    P0              65W / 699W |     88MiB / 95830MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | MIG devices:                                                                          |
# +------------------+--------------------------------+-----------+-----------------------+
# | GPU  GI  CI  MIG |                   Memory-Usage |        Vol|      Shared           |
# |      ID  ID  Dev |                     BAR1-Usage | SM     Unc| CE ENC DEC OFA JPG    |
# |                  |                                |        ECC|                       |
# |==================+================================+===========+=======================|
# |  0    2   0   0  |              37MiB / 47488MiB  | 60      0 |  3   0    3    0    3 |
# |                  |               0MiB / 65535MiB  |           |                       |
# +------------------+--------------------------------+-----------+-----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# Home
# %cd /home/7/ut03197
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/7/ut03197
# /home/7/ut03197

# %%
# Clone and install YOLOv9
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# !pip install pickleshare
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (216/216), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 325 (delta 158), reused 155 (delta 155), pack-reused 109
# Receiving objects: 100% (325/325), 2.23 MiB | 7.00 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /home/7/ut03197/yolov9
# /apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#   WARNING: The script tqdm is installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy is installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script f2py is installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts lsm2bin, tiff2fsspec, tiffcomment and tifffile are installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py is installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts imageio_download_bin and imageio_remove_bin are installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard is installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2 and torchrun are installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: pickleshare
# Successfully installed pickleshare-0.7.5

# %%
# Download YOLOv9 pre-trained model weights
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# See the downloaded weights
# !ls -la {HOME}/weights
# Out:
# total 151048
# drwxr-xr-x  2 ut03197 tsubame-users      4096 May  5 17:08 .
# drwx------ 13 ut03197 tsubame-users      4096 May  9 19:21 ..
# -rw-r--r--  1 ut03197 tsubame-users  51508261 Feb 18 21:36 gelan-c.pt
# -rw-r--r--  1 ut03197 tsubame-users 103153312 Feb 18 21:36 yolov9-c.pt

# %%
# Go back to appropriate directory to download the dataset
# %cd {HOME}/yolov9
# Out:
# /home/7/ut03197/yolov9

# %%
# Run this command to add the directory to your PATH
# !export PATH="$PATH:/home/7/ut03197/.local/bin"

# %%
# !pip install roboflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting roboflow
#   Downloading roboflow-1.1.28-py3-none-any.whl.metadata (9.3 kB)
# Collecting certifi==2023.7.22 (from roboflow)
#   Downloading certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl.metadata (722 bytes)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/7/ut03197/.local/lib/python3.9/site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /home/7/ut03197/.local/lib/python3.9/site-packages (from roboflow) (3.8.4)
# Requirement already satisfied: numpy>=1.18.5 in /home/7/ut03197/.local/lib/python3.9/site-packages (from roboflow) (1.26.4)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /home/7/ut03197/.local/lib/python3.9/site-packages (from roboflow) (10.3.0)
# Requirement already satisfied: python-dateutil in /apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/site-packages (from roboflow) (2.2.1)
# Requirement already satisfied: tqdm>=4.41.0 in /home/7/ut03197/.local/lib/python3.9/site-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/site-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/7/ut03197/.local/lib/python3.9/site-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/7/ut03197/.local/lib/python3.9/site-packages (from matplotlib->roboflow) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in /apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/site-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/7/ut03197/.local/lib/python3.9/site-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/7/ut03197/.local/lib/python3.9/site-packages (from matplotlib->roboflow) (6.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib64/python3.9/site-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: zipp>=3.1.0 in /apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.18.1)
# Downloading roboflow-1.1.28-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 6.5 MB/s eta 0:00:00
# Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 16.0 MB/s eta 0:00:00
# Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 15.3 MB/s eta 0:00:00
# Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.2 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 34.0 MB/s eta 0:00:00:00:0100:01
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: python-magic, python-dotenv, opencv-python-headless, idna, cycler, chardet, certifi, requests-toolbelt, roboflow
#   WARNING: The script dotenv is installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   WARNING: The script chardetect is installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script roboflow is installed in '/home/7/ut03197/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.6 requires opencv-python-headless>=4.9.0, but you have opencv-python-headless 4.8.0.74 which is incompatible.
# Successfully installed certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 python-dotenv-1.0.1 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.28

# %%
# !pip install roboflow
# %cd {HOME}/yolov9

from roboflow import Roboflow
rf = Roboflow(api_key="################") # api_key removed
project = rf.workspace("specialist").project("vehicle-detection-poribohon-bd")
version = project.version(1)
dataset = version.download("yolov9")

# %%
# Hyperparameter tuning
# See the hyperparameters
# Install necessary libraries if not already installed
# !pip install pyyaml

# Import required libraries
import yaml

# Define the file name
file_name = f"{HOME}/yolov9/data/hyps/hyp.scratch-high.yaml"

# Read the content from the YAML file
with open(file_name, 'r') as file:
    yaml_data = yaml.safe_load(file)

# Print the content of the YAML file
print(yaml.dump(yaml_data))

# %%
# Update the hyperparameters if needed, otherwise IGNORE

# Read the content from the YAML file
with open(file_name, 'r') as file:
    yaml_data = yaml.safe_load(file)

# Update the hyperparameters with the new values
new_hyperparameters = {
    # 'lrf': 0.01,   
    'momentum': 0.85,
    'mixup': 0.2,
    # 'lr0' : 0.01,
    'warmup_momentum': .7
}

# Update the hyperparameters with the new values
for key, value in new_hyperparameters.items():
    yaml_data[key] = value

# Write the updated content back to the YAML file
with open(file_name, 'w') as file:
    yaml.dump(yaml_data, file)

print("YAML file updated successfully.")

# Print after update

# Read the content from the YAML file
with open(file_name, 'r') as file:
    yaml_data = yaml.safe_load(file)

# Print the content of the YAML file
print(yaml.dump(yaml_data))

# %%
### TRAINING 
# %cd {HOME}/yolov9

# Train yolov9.c model 
# !python train_dual.py \
--batch 32 --epochs 40 --img 640 --device 0 --min-items 0 --close-mosaic 5 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/yolov9-c.pt \
--cfg models/detect/yolov9-c.yaml \
--hyp hyp.scratch-high.yaml


# # Train gelan.c model
# !python train.py \
# --batch 32 --epochs 40 --img 640 --device 0 --min-items 0 --close-mosaic 5 \
# --data {dataset.location}/data.yaml \
# --weights {HOME}/weights/gelan-c.pt \
# --cfg models/detect/gelan-c.yaml \
# --hyp hyp.scratch-high.yaml
# Out:
# /home/7/ut03197/yolov9
# train_dual: weights=/home/7/ut03197/weights/yolov9-c.pt, cfg=models/detect/yolov9-c.yaml, data=/home/7/ut03197/yolov9/vehicle-detection-Poribohon-BD-1/data.yaml, hyp=hyp.scratch-high.yaml, epochs=40, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=5, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.9.18 torch-2.3.0+cu121 CUDA:0 (NVIDIA H100 MIG 3g.47gb, 47488MiB)
#
# hyperparameters: anchor_t=5.0, box=7.5, cls=0.5, cls_pw=1.0, copy_paste=0.3, degrees=0.0, dfl=1.5, fl_gamma=0.0, fliplr=0.5, flipud=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, iou_t=0.2, lr0=0.01, lrf=0.01, mixup=0.2, momentum=0.85, mosaic=1.0, obj_pw=1.0, perspective=0.0, scale=0.9, shear=0.0, translate=0.1, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.7, weight_decay=0.0005
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=15
#
#                  from  n    params  module                                  arguments
#   0                -1  1         0  models.common.Silence                   []
#   1                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   2                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   3                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   4                -1  1    164352  models.common.ADown                     [256, 256]
#   5                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   6                -1  1    656384  models.common.ADown                     [512, 512]
#   7                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   8                -1  1    656384  models.common.ADown                     [512, 512]
#   9                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#  10                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 7]  1         0  models.common.Concat                    [1]
#  13                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  14                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  15           [-1, 5]  1         0  models.common.Concat                    [1]
#  16                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  17                -1  1
28        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.916      0.854      0.922      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/39      44.1G      1.337     0.9999      1.605         43        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.911      0.867      0.924      0.693
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/39      44.1G      1.329      0.992      1.601         21        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.908      0.871      0.923      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/39      44.1G      1.319     0.9665      1.589         16        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.902       0.87      0.925      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/39      44.1G      1.307      0.952      1.586         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575       0.92       0.87      0.925      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/39      44.1G      1.299     0.9361      1.578         24        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.909      0.879      0.928      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/39      44.1G      1.283     0.9181      1.574         29        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.923      0.864      0.927      0.699
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/39      44.1G      1.273     0.9001      1.563         37        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.925       0.87      0.929      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/39      44.1G      1.261     0.8915       1.55         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575       0.92      0.875       0.93      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/39      44.1G      1.248     0.8699      1.542         44        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.928      0.876      0.932      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/39      46.4G      1.243      0.864      1.529         28        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.933      0.868       0.93      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/39      46.4G      1.232     0.8549      1.527         28        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.923      0.881      0.932      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/39      46.4G      1.213     0.8385      1.514         40        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.924      0.873      0.932      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/39      38.6G      1.205      0.828      1.511         68        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.921      0.881      0.932      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/39        40G      1.185     0.8057      1.503         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.919      0.886      0.932       0.71
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/39        40G      1.177     0.7917      1.493         26        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.922      0.882      0.933      0.711
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/39        40G      1.079     0.5824      1.501         20        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.922      0.879      0.933      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/39        40G      1.053     0.5587      1.484         14        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.924      0.875      0.931      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/39        40G      1.036     0.5482      1.475          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.928      0.872      0.932      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/39        40G       1.02     0.5316      1.456         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.935      0.868      0.933      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/39        40G     0.9989     0.5184      1.443          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.928      0.869      0.933      0.712
#
# 40 epochs completed in 5.064 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 102.9MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 102.9MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# yolov9-c summary: 724 layers, 50990970 parameters, 0 gradients, 237.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   Exception in thread Thread-54:
# Traceback (most recent call last):
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 300, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 86, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-53:
# Traceback (most recent call last):
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 300, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 86, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#                  Class     Images  Instances          P          R      mAP50   Exception in thread Thread-56:
# Traceback (most recent call last):
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 300, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 86, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-55:
# Traceback (most recent call last):
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 300, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 86, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#                  Class     Images  Instances          P          R      mAP50   Exception in thread Thread-58:
# Traceback (most recent call last):
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 300, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 86, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
# Exception in thread Thread-57:
# Traceback (most recent call last):
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/apps/t4/rhel9/free/jupyterlab/4.1.4/gcc11.4.1/python3.9.18_b/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 300, in plot_images
#     annotator.box_label(box, label, color=color)
#   File "/home/7/ut03197/yolov9/utils/plots.py", line 86, in box_label
#     w, h = self.font.getsize(label)  # text width, height
# AttributeError: 'FreeTypeFont' object has no attribute 'getsize'
#                  Class     Images  Instances          P          R      mAP50
#                    all        901       2575      0.922      0.879      0.933      0.712
#                bicycle        901        119      0.855      0.891      0.925      0.666
#                   bike        901        172      0.952      0.855      0.934      0.706
#                   boat        901        298      0.859      0.759      0.856       0.53
#                    bus        901        169      0.974      0.871      0.942      0.729
#                    car        901        308      0.896      0.825      0.908      0.659
#                    cng        901        207      0.969       0.92      0.964      0.765
#               easybike        901        144       0.98      0.979      0.991      0.819
#              horsecart        901         36      0.921          1      0.994      0.808
#                 launch        901        166      0.856      0.807      0.885      0.637
#                 leguna        901         69      0.922      0.928      0.975      0.881
#               rickshaw        901        384      0.884      0.755      0.859       0.59
#                tractor        901         82      0.945      0.951      0.956      0.785
#                  truck        901        146      0.951       0.87      0.943      0.743
#                    van        901        207      0.939      0.892      0.946      0.721
#            wheelbarrow        901         68      0.932      0.882       0.92      0.649
# Results saved to runs/train/exp

# %%
# # Validate custom model

# !python val_dual.py \
# --img 640 --batch 32 --conf 0.01 --iou 0.5 --device 0 \
# --data {dataset.location}/data.yaml \
# --weights {HOME}/runs/train/exp/weights/best.pt
